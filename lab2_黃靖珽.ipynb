# %% [markdown]
# <div align="center">
#
# ###### Lab 2
#
# # National Tsing Hua University
#
# #### Spring 2024
#
# #### 11220IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 2: Predicting Heart Disease with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In the realm of healthcare, early detection and accurate prediction of diseases play a crucial role in patient care and management. Heart disease remains one of the leading causes of mortality worldwide, making the development of effective diagnostic tools essential. This lab leverages deep learning to predict the presence of heart disease in patients using a subset of 14 key attributes from the Cleveland Heart Disease Database. The objective is to explore and apply deep learning techniques to distinguish between the presence and absence of heart disease based on clinical parameters.
#
# Throughout this lab, you'll engage with the following key activities:
# - Use [Pandas](https://pandas.pydata.org) to process the CSV files.
# - Use [PyTorch](https://pytorch.org) to build an Artificial Neural Network (ANN) to fit the dataset.
# - Evaluate the performance of the trained model to understand its accuracy.
#
# ### Attribute Information
#
# 1. age: Age of the patient in years
# 2. sex: (Male/Female)
# 3. cp: Chest pain type (4 types: low, medium, high, and severe)
# 4. trestbps: Resting blood pressure
# 5. chol: Serum cholesterol in mg/dl
# 6. fbs: Fasting blood sugar > 120 mg/dl
# 7. restecg: Resting electrocardiographic results (values 0,1,2)
# 8. thalach: Maximum heart rate achieved
# 9. exang: Exercise induced angina
# 10. oldpeak: Oldpeak = ST depression induced by exercise relative to rest
# 11. slope: The slope of the peak exercise ST segment
# 12. ca: Number of major vessels (0-3) colored by fluoroscopy
# 13. thal: 3 = normal; 6 = fixed defect; 7 = reversible defect
# 14. target: target have disease or not (1=yes, 0=no)
#
# ### References
# - [UCI Heart Disease Data](https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data) for the dataset we use in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/Shareddrives/碩士/深度學習產業應用/week3/heart_dataset_train_all.csv')
df
# Out:
#      age     sex      cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0     41    Male  medium     105.0  198.0    0      1.0    168.0      0
# 1     65  Female     low     120.0  177.0    0      1.0    140.0      0
# 2     44  Female  medium     130.0  219.0    0      0.0    188.0      0
# 3     54  Female    high     125.0  273.0    0      0.0    152.0      0
# 4     51  Female  severe     125.0  213.0    0      0.0    125.0      1
# ..   ...     ...     ...       ...    ...  ...      ...      ...    ...
# 268   40  Female     low     110.0  167.0    0      0.0    114.0      1
# 269   60  Female     low     117.0  230.0    1      1.0    160.0      1
# 270   64  Female    high     140.0  335.0    0      1.0    158.0      0
# 271   43  Female     low     120.0  177.0    0      0.0    120.0      1
# 272   57  Female     low     150.0  276.0    0      0.0    112.0      1
#
#      oldpeak  slope  ca  thal  target
# 0        0.0    2.0   1   2.0     1.0
# 1        0.4    2.0   0   3.0     1.0
# 2        0.0    2.0   0   2.0     1.0
# 3        0.5    0.0   1   2.0     1.0
# 4        1.4    2.0   1   2.0     1.0
# ..       ...    ...  ..   ...     ...
# 268      2.0    1.0   0   3.0     0.0
# 269      1.4    2.0   2   3.0     0.0
# 270      0.0    2.0   0   2.0     0.0
# 271      2.5    1.0   0   3.0     0.0
# 272      0.6    1.0   1   1.0     0.0
#
# [273 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       273 non-null    int64
#  1   sex       272 non-null    object
#  2   cp        272 non-null    object
#  3   trestbps  272 non-null    float64
#  4   chol      271 non-null    float64
#  5   fbs       273 non-null    int64
#  6   restecg   272 non-null    float64
#  7   thalach   272 non-null    float64
#  8   exang     273 non-null    int64
#  9   oldpeak   273 non-null    float64
#  10  slope     271 non-null    float64
#  11  ca        273 non-null    int64
#  12  thal      272 non-null    float64
#  13  target    272 non-null    float64
# dtypes: float64(8), int64(4), object(2)
# memory usage: 30.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# age         0
# sex         1
# cp          1
# trestbps    1
# chol        2
# fbs         0
# restecg     1
# thalach     1
# exang       0
# oldpeak     0
# slope       2
# ca          0
# thal        1
# target      1
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (270, 14)

# %%
# Mapping 'sex' descriptions to numbers
sex_description = {
    'Male': 0,
    'Female': 1,
}
df.loc[:, 'sex'] = df['sex'].map(sex_description)

# Mapping 'cp' (chest pain) descriptions to numbers
pain_description = {
    'low': 0,
    'medium': 1,
    'high': 2,
    'severe': 3
}
df.loc[:, 'cp'] = df['cp'].map(pain_description)

df
# Out:
# <ipython-input-80-39abb612ef0e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'sex'] = df['sex'].map(sex_description)
# <ipython-input-80-39abb612ef0e>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'sex'] = df['sex'].map(sex_description)
# <ipython-input-80-39abb612ef0e>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'cp'] = df['cp'].map(pain_description)
# <ipython-input-80-39abb612ef0e>:15: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'cp'] = df['cp'].map(pain_description)
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     41    0   1     105.0  198.0    0      1.0    168.0      0      0.0
# 1     65    1   0     120.0  177.0    0      1.0    140.0      0      0.4
# 2     44    1   1     130.0  219.0    0      0.0    188.0      0      0.0
# 3     54    1   2     125.0  273.0    0      0.0    152.0      0      0.5
# 4     51    1   3     125.0  213.0    0      0.0    125.0      1      1.4
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 268   40    1   0     110.0  167.0    0      0.0    114.0      1      2.0
# 269   60    1   0     117.0  230.0    1      1.0    160.0      1      1.4
# 270   64    1   2     140.0  335.0    0      1.0    158.0      0      0.0
# 271   43    1   0     120.0  177.0    0      0.0    120.0      1      2.5
# 272   57    1   0     150.0  276.0    0      0.0    112.0      1      0.6
#
#      slope  ca  thal  target
# 0      2.0   1   2.0     1.0
# 1      2.0   0   3.0     1.0
# 2      2.0   0   2.0     1.0
# 3      0.0   1   2.0     1.0
# 4      2.0   1   2.0     1.0
# ..     ...  ..   ...     ...
# 268    1.0   0   3.0     0.0
# 269    2.0   2   3.0     0.0
# 270    2.0   0   2.0     0.0
# 271    1.0   0   3.0     0.0
# 272    1.0   1   1.0     0.0
#
# [270 rows x 14 columns]

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.385185    0.685185    0.962963  131.525926  245.607407    0.151852
# std      9.149713    0.465305    1.023206   17.904675   51.529411    0.359544
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.250000    0.000000    0.000000  120.000000  210.250000    0.000000
# 50%     56.000000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     0.522222  149.807407    0.333333    1.024074    1.400000    0.744444
# std      0.529314   23.217253    0.472280    1.188379    0.618188    1.037166
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  134.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.600000    1.000000    0.000000
# 75%      1.000000  167.750000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  270.000000  270.000000
# mean     2.300000    0.544444
# std      0.623874    0.498946
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.062222 -0.103697  0.261782  0.210520  0.109847
# sex      -0.062222  1.000000 -0.040197 -0.055463 -0.166885  0.042384
# cp       -0.103697 -0.040197  1.000000  0.035563 -0.063592  0.065869
# trestbps  0.261782 -0.055463  0.035563  1.000000  0.128444  0.170606
# chol      0.210520 -0.166885 -0.063592  0.128444  1.000000  0.003430
# fbs       0.109847  0.042384  0.065869  0.170606  0.003430  1.000000
# restecg  -0.124588 -0.069599  0.008389 -0.145195 -0.162687 -0.086165
# thalach  -0.412624 -0.058626  0.300307 -0.056631 -0.023753 -0.014297
# exang     0.111263  0.124054 -0.428233  0.067116  0.063902  0.029190
# oldpeak   0.200243  0.089726 -0.183616  0.184896  0.084355  0.007943
# slope    -0.165360 -0.038771  0.135174 -0.126553 -0.031929 -0.056866
# ca        0.254462  0.140795 -0.180598  0.093545  0.068647  0.164266
# thal      0.077368  0.198493 -0.139765  0.068690  0.121280 -0.004972
# target   -0.244798 -0.283776  0.425574 -0.173239 -0.096773 -0.068845
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.124588 -0.412624  0.111263  0.200243 -0.165360  0.254462
# sex      -0.069599 -0.058626  0.124054  0.089726 -0.038771  0.140795
# cp        0.008389  0.300307 -0.428233 -0.183616  0.135174 -0.180598
# trestbps -0.145195 -0.056631  0.067116  0.184896 -0.126553  0.093545
# chol     -0.162687 -0.023753  0.063902  0.084355 -0.031929  0.068647
# fbs      -0.086165 -0.014297  0.029190  0.007943 -0.056866  0.164266
# restecg   1.000000  0.025457 -0.089225 -0.047837  0.074982 -0.053946
# thalach   0.025457  1.000000 -0.404349 -0.340564  0.370073 -0.205060
# exang    -0.089225 -0.404349  1.000000  0.294308 -0.280124  0.106250
# oldpeak  -0.047837 -0.340564  0.294308  1.000000 -0.585472  0.223375
# slope     0.074982  0.370073 -0.280124 -0.585472  1.000000 -0.083491
# ca       -0.053946 -0.205060  0.106250  0.223375 -0.083491  1.000000
# thal     -0.003377 -0.078637  0.189253  0.200315 -0.090606  0.136160
# target    0.101817  0.432687 -0.457502 -0.443504  0.363983 -0.391031
#
#               thal    target
# age       0.077368 -0.244798
# sex       0.198493 -0.283776
# cp       -0.139765  0.425574
# trestbps  0.068690 -0.173239
# chol      0.121280 -0.096773
# fbs      -0.004972 -0.068845
# restecg  -0.003377  0.101817
# thalach  -0.078637  0.432687
# exang     0.189253 -0.457502
# oldpeak   0.200315 -0.443504
# slope    -0.090606  0.363983
# ca        0.136160 -0.391031
# thal      1.000000 -0.311701
# target   -0.311701  1.000000

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
import numpy as np

np_data = df.values
np_data.shape
# Out:
# (270, 14)

# %%
split_point = int(np_data.shape[0]*0.7)

np.random.shuffle(np_data)

x_train = np_data[:split_point, :13]
y_train = np_data[:split_point, 13]
x_val = np_data[split_point:, :13]
y_val = np_data[split_point:, 13]

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).long()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).long()

batch_size = 48

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Number of samples in train and validation are 189 and 81.

# %% [markdown]
# ## B. Defining Neural Networks
#
# In PyTorch, we can use **class** to define our custom neural network architectures by subclassing the `nn.Module` class. This gives our neural network all the functionality it needs to work with PyTorch's other utilities and keeps our implementation organized.
#
# - Neural networks are defined by subclassing `nn.Module`.
# - The layers of the neural network are initialized in the `__init__` method.
# - The forward pass operations on input data are defined in the `forward` method.
#
# It's worth noting that while we only define the forward pass, PyTorch will automatically derive the backward pass for us, which is used during training to update the model's weights."

# %%
import torch.nn as nn

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(13, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        ).cuda()

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Sun Mar 17 07:50:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P0              30W /  70W |    161MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 120

model = Model()
# print(model)

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()

            outputs = model(features)

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 1/120, Train loss: 8.6180, Train acc: 49.2063%, Val loss: 11.2160, Val acc: 50.6173%, Best Val loss: 11.2160 Best Val acc: 50.62%
# Epoch 2/120, Train loss: 11.2218, Train acc: 56.0847%, Val loss: 6.6634, Val acc: 50.6173%, Best Val loss: 6.6634 Best Val acc: 50.62%
# Epoch 3/120, Train loss: 4.9957, Train acc: 56.6138%, Val loss: 7.2355, Val acc: 49.3827%, Best Val loss: 6.6634 Best Val acc: 50.62%
# Epoch 4/120, Train loss: 4.3871, Train acc: 53.4392%, Val loss: 5.5647, Val acc: 50.6173%, Best Val loss: 5.5647 Best Val acc: 50.62%
# Epoch 5/120, Train loss: 4.8283, Train acc: 56.0847%, Val loss: 1.0451, Val acc: 61.7284%, Best Val loss: 1.0451 Best Val acc: 61.73%
# Epoch 6/120, Train loss: 2.6245, Train acc: 49.7354%, Val loss: 1.9307, Val acc: 56.7901%, Best Val loss: 1.0451 Best Val acc: 61.73%
# Epoch 7/120, Train loss: 1.8039, Train acc: 62.9630%, Val loss: 2.8557, Val acc: 53.0864%, Best Val loss: 1.0451 Best Val acc: 61.73%
# Epoch 8/120, Train loss: 1.7237, Train acc: 61.3757%, Val loss: 1.6628, Val acc: 60.4938%, Best Val loss: 1.0451 Best Val acc: 61.73%
# Epoch 9/120, Train loss: 1.3576, Train acc: 62.9630%, Val loss: 1.2048, Val acc: 60.4938%, Best Val loss: 1.0451 Best Val acc: 61.73%
# Epoch 10/120, Train loss: 1.0311, Train acc: 68.2540%, Val loss: 0.7882, Val acc: 70.3704%, Best Val loss: 0.7882 Best Val acc: 70.37%
# Epoch 11/120, Train loss: 0.8465, Train acc: 69.3122%, Val loss: 0.7701, Val acc: 67.9012%, Best Val loss: 0.7701 Best Val acc: 70.37%
# Epoch 12/120, Train loss: 0.9265, Train acc: 68.7831%, Val loss: 0.7691, Val acc: 65.4321%, Best Val loss: 0.7691 Best Val acc: 70.37%
# Epoch 13/120, Train loss: 0.8315, Train acc: 68.7831%, Val loss: 0.7789, Val acc: 61.7284%, Best Val loss: 0.7691 Best Val acc: 70.37%
# Epoch 14/120, Train loss: 0.7614, Train acc: 66.6667%, Val loss: 0.7168, Val acc: 69.1358%, Best Val loss: 0.7168 Best Val acc: 70.37%
# Epoch 15/120, Train loss: 0.7507, Train acc: 65.0794%, Val loss: 0.9274, Val acc: 60.4938%, Best Val loss: 0.7168 Best Val acc: 70.37%
# Epoch 16/120, Train loss: 0.7072, Train acc: 68.2540%, Val loss: 0.7400, Val acc: 65.4321%, Best Val loss: 0.7168 Best Val acc: 70.37%
# Epoch 17/120, Train loss: 0.5930, Train acc: 69.8413%, Val loss: 0.6747, Val acc: 61.7284%, Best Val loss: 0.6747 Best Val acc: 70.37%
# Epoch 18/120, Train loss: 0.5493, Train acc: 69.3122%, Val loss: 0.6105, Val acc: 67.9012%, Best Val loss: 0.6105 Best Val acc: 70.37%
# Epoch 19/120, Train loss: 0.5447, Train acc: 74.0741%, Val loss: 0.5938, Val acc: 66.6667%, Best Val loss: 0.5938 Best Val acc: 70.37%
# Epoch 20/120, Train loss: 0.5330, Train acc: 74.6032%, Val loss: 0.6110, Val acc: 61.7284%, Best Val loss: 0.5938 Best Val acc: 70.37%
# Epoch 21/120, Train loss: 0.5304, Train acc: 73.5450%, Val loss: 0.6320, Val acc: 60.4938%, Best Val loss: 0.5938 Best Val acc: 70.37%
# Epoch 22/120, Train loss: 0.5541, Train acc: 71.4286%, Val loss: 0.6219, Val acc: 67.9012%, Best Val loss: 0.5938 Best Val acc: 70.37%
# Epoch 23/120, Train loss: 0.5472, Train acc: 72.4868%, Val loss: 0.5841, Val acc: 67.9012%, Best Val loss: 0.5841 Best Val acc: 70.37%
# Epoch 24/120, Train loss: 0.5509, Train acc: 70.8995%, Val loss: 0.5817, Val acc: 67.9012%, Best Val loss: 0.5817 Best Val acc: 70.37%
# Epoch 25/120, Train loss: 0.5229, Train acc: 76.1905%, Val loss: 0.6338, Val acc: 60.4938%, Best Val loss: 0.5817 Best Val acc: 70.37%
# Epoch 26/120, Train loss: 0.5642, Train acc: 68.7831%, Val loss: 0.7252, Val acc: 61.7284%, Best Val loss: 0.5817 Best Val acc: 70.37%
# Epoch 27/120, Train loss: 0.5904, Train acc: 70.3704%, Val loss: 0.5892, Val acc: 66.6667%, Best Val loss: 0.5817 Best Val acc: 70.37%
# Epoch 28/120, Train loss: 0.5168, Train acc: 73.5450%, Val loss: 0.5983, Val acc: 64.1975%, Best Val loss: 0.5817 Best Val acc: 70.37%
# Epoch 29/120, Train loss: 0.5357, Train acc: 74.0741%, Val loss: 0.6363, Val acc: 66.6667%, Best Val loss: 0.5817 Best Val acc: 70.37%
# Epoch 30/120, Train loss: 0.5531, Train acc: 71.9577%, Val loss: 0.5786, Val acc: 70.3704%, Best Val loss: 0.5786 Best Val acc: 70.37%
# Epoch 31/120, Train loss: 0.5107, Train acc: 75.6614%, Val loss: 0.8744, Val acc: 60.4938%, Best Val loss: 0.5786 Best Val acc: 70.37%
# Epoch 32/120, Train loss: 0.5877, Train acc: 69.3122%, Val loss: 0.6840, Val acc: 65.4321%, Best Val loss: 0.5786 Best Val acc: 70.37%
# Epoch 33/120, Train loss: 0.5963, Train acc: 69.3122%, Val loss: 0.5865, Val acc: 70.3704%, Best Val loss: 0.5786 Best Val acc: 70.37%
# Epoch 34/120, Train loss: 0.5908, Train acc: 65.6085%, Val loss: 0.6090, Val acc: 61.7284%, Best Val loss: 0.5786 Best Val acc: 70.37%
# Epoch 35/120, Train loss: 0.5168, Train acc: 73.5450%, Val loss: 0.6127, Val acc: 59.2593%, Best Val loss: 0.5786 Best Val acc: 70.37%
# Epoch 36/120, Train loss: 0.5773, Train acc: 67.7249%, Val loss: 0.5796, Val acc: 65.4321%, Best Val loss: 0.5786 Best Val acc: 70.37%
# Epoch 37/120, Train loss: 0.5629, Train acc: 71.9577%, Val loss: 0.6721, Val acc: 64.1975%, Best Val loss: 0.5786 Best Val acc: 70.37%
# Epoch 38/120, Train loss: 0.5529, Train acc: 71.9577%, Val loss: 0.5737, Val acc: 67.9012%, Best Val loss: 0.5737 Best Val acc: 70.37%
# Epoch 39/120, Train loss: 0.5229, Train acc: 74.6032%, Val loss: 0.6061, Val acc: 61.7284%, Best Val loss: 0.5737 Best Val acc: 70.37%
# Epoch 40/120, Train loss: 0.4834, Train acc: 75.1323%, Val loss: 0.5766, Val acc: 74.0741%, Best Val loss: 0.5737 Best Val acc: 74.07%
# Epoch 41/120, Train loss: 0.4987, Train acc: 76.1905%, Val loss: 0.5643, Val acc: 67.9012%, Best Val loss: 0.5643 Best Val acc: 74.07%
# Epoch 42/120, Train loss: 0.4748, Train acc: 77.2487%, Val loss: 0.5595, Val acc: 66.6667%, Best Val loss: 0.5595 Best Val acc: 74.07%
# Epoch 43/120, Train loss: 0.4864, Train acc: 76.7196%, Val loss: 0.5842, Val acc: 64.1975%, Best Val loss: 0.5595 Best Val acc: 74.07%
# Epoch 44/120, Train loss: 0.4708, Train acc: 78.3069%, Val loss: 0.5730, Val acc: 72.8395%, Best Val loss: 0.5595 Best Val acc: 74.07%
# Epoch 45/120, Train loss: 0.4891, Train acc: 74.0741%, Val loss: 0.5662, Val acc: 72.8395%, Best Val loss: 0.5595 Best Val acc: 74.07%
# Epoch 46/120, Train loss: 0.5159, Train acc: 70.8995%, Val loss: 0.6622, Val acc: 61.7284%, Best Val loss: 0.5595 Best Val acc: 74.07%
# Epoch 47/120, Train loss: 0.5683, Train acc: 69.8413%, Val loss: 0.6369, Val acc: 62.9630%, Best Val loss: 0.5595 Best Val acc: 74.07%
# Epoch 48/120, Train loss: 0.5203, Train acc: 74.0741%, Val loss: 0.6585, Val acc: 64.1975%, Best Val loss: 0.5595 Best Val acc: 74.07%
# Epoch 49/120, Train loss: 0.5950, Train acc: 69.3122%, Val loss: 0.5513, Val acc: 66.6667%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 50/120, Train loss: 0.5579, Train acc: 69.3122%, Val loss: 0.9656, Val acc: 60.4938%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 51/120, Train loss: 0.6872, Train acc: 69.3122%, Val loss: 1.1783, Val acc: 53.0864%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 52/120, Train loss: 0.8219, Train acc: 62.4339%, Val loss: 1.2888, Val acc: 56.7901%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 53/120, Train loss: 0.7128, Train acc: 67.1958%, Val loss: 1.2758, Val acc: 53.0864%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 54/120, Train loss: 0.7284, Train acc: 64.5503%, Val loss: 1.2398, Val acc: 59.2593%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 55/120, Train loss: 0.6977, Train acc: 70.3704%, Val loss: 0.9451, Val acc: 61.7284%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 56/120, Train loss: 0.5796, Train acc: 71.4286%, Val loss: 1.0717, Val acc: 62.9630%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 57/120, Train loss: 0.7604, Train acc: 67.1958%, Val loss: 0.7609, Val acc: 66.6667%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 58/120, Train loss: 0.5369, Train acc: 73.5450%, Val loss: 0.8352, Val acc: 61.7284%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 59/120, Train loss: 0.5565, Train acc: 72.4868%, Val loss: 0.7612, Val acc: 64.1975%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 60/120, Train loss: 0.6146, Train acc: 70.3704%, Val loss: 0.7389, Val acc: 61.7284%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 61/120, Train loss: 0.5702, Train acc: 71.4286%, Val loss: 0.6626, Val acc: 65.4321%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 62/120, Train loss: 0.5400, Train acc: 67.7249%, Val loss: 0.6063, Val acc: 62.9630%, Best Val loss: 0.5513 Best Val acc: 74.07%
# Epoch 63/120, Train loss: 0.4912, Train acc: 74.6032%, Val loss: 0.5368, Val acc: 74.0741%, Best Val loss: 0.5368 Best Val acc: 74.07%
# Epoch 64/120, Train loss: 0.4509, Train acc: 82.0106%, Val loss: 0.5534, Val acc: 66.6667%, Best Val loss: 0.5368 Best Val acc: 74.07%
# Epoch 65/120, Train loss: 0.4639, Train acc: 78.8360%, Val loss: 0.5325, Val acc: 72.8395%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 66/120, Train loss: 0.4595, Train acc: 78.3069%, Val loss: 0.5364, Val acc: 71.6049%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 67/120, Train loss: 0.4518, Train acc: 75.6614%, Val loss: 0.5430, Val acc: 67.9012%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 68/120, Train loss: 0.4372, Train acc: 79.3651%, Val loss: 0.5384, Val acc: 70.3704%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 69/120, Train loss: 0.4380, Train acc: 80.4233%, Val loss: 0.5428, Val acc: 67.9012%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 70/120, Train loss: 0.4711, Train acc: 77.7778%, Val loss: 0.5356, Val acc: 69.1358%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 71/120, Train loss: 0.4416, Train acc: 79.3651%, Val loss: 0.5363, Val acc: 69.1358%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 72/120, Train loss: 0.4421, Train acc: 79.8942%, Val loss: 0.5328, Val acc: 72.8395%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 73/120, Train loss: 0.4427, Train acc: 79.3651%, Val loss: 0.5383, Val acc: 69.1358%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 74/120, Train loss: 0.4334, Train acc: 79.8942%, Val loss: 0.5434, Val acc: 70.3704%, Best Val loss: 0.5325 Best Val acc: 74.07%
# Epoch 75/120, Train loss: 0.4391, Train acc: 79.8942%, Val loss: 0.5286, Val acc: 72.8395%, Best Val loss: 0.5286 Best Val acc: 74.07%
# Epoch 76/120, Train loss: 0.4332, Train acc: 80.4233%, Val loss: 0.5373, Val acc: 71.6049%, Best Val loss: 0.5286 Best Val acc: 74.07%
# Epoch 77/120, Train loss: 0.4627, Train acc: 77.2487%, Val loss: 0.5225, Val acc: 72.8395%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 78/120, Train loss: 0.4997, Train acc: 76.7196%, Val loss: 0.5280, Val acc: 71.6049%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 79/120, Train loss: 0.4489, Train acc: 78.8360%, Val loss: 0.5346, Val acc: 71.6049%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 80/120, Train loss: 0.4261, Train acc: 81.4815%, Val loss: 0.5705, Val acc: 67.9012%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 81/120, Train loss: 0.4404, Train acc: 77.7778%, Val loss: 0.5378, Val acc: 71.6049%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 82/120, Train loss: 0.4339, Train acc: 79.3651%, Val loss: 0.5532, Val acc: 69.1358%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 83/120, Train loss: 0.4490, Train acc: 79.3651%, Val loss: 0.5229, Val acc: 72.8395%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 84/120, Train loss: 0.4408, Train acc: 79.3651%, Val loss: 0.5311, Val acc: 72.8395%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 85/120, Train loss: 0.4498, Train acc: 79.3651%, Val loss: 0.5665, Val acc: 67.9012%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 86/120, Train loss: 0.4232, Train acc: 81.4815%, Val loss: 0.5492, Val acc: 72.8395%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 87/120, Train loss: 0.4459, Train acc: 77.2487%, Val loss: 0.5351, Val acc: 71.6049%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 88/120, Train loss: 0.4283, Train acc: 80.9524%, Val loss: 0.5260, Val acc: 71.6049%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 89/120, Train loss: 0.4206, Train acc: 82.0106%, Val loss: 0.5279, Val acc: 72.8395%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 90/120, Train loss: 0.4399, Train acc: 81.4815%, Val loss: 0.5394, Val acc: 71.6049%, Best Val loss: 0.5225 Best Val acc: 74.07%
# Epoch 91/120, Train loss: 0.4190, Train acc: 80.9524%, Val loss: 0.5224, Val acc: 74.0741%, Best Val loss: 0.5224 Best Val acc: 74.07%
# Epoch 92/120, Train loss: 0.4235, Train acc: 81.4815%, Val loss: 0.5197, Val acc: 72.8395%, Best Val loss: 0.5197 Best Val acc: 74.07%
# Epoch 93/120, Train loss: 0.4189, Train acc: 81.4815%, Val loss: 0.5288, Val acc: 74.0741%, Best Val loss: 0.5197 Best Val acc: 74.07%
# Epoch 94/120, Train loss: 0.4232, Train acc: 79.3651%, Val loss: 0.5192, Val acc: 72.8395%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 95/120, Train loss: 0.4276, Train acc: 80.4233%, Val loss: 0.5266, Val acc: 74.0741%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 96/120, Train loss: 0.4151, Train acc: 79.8942%, Val loss: 0.5202, Val acc: 72.8395%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 97/120, Train loss: 0.4242, Train acc: 80.9524%, Val loss: 0.5206, Val acc: 74.0741%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 98/120, Train loss: 0.4135, Train acc: 80.4233%, Val loss: 0.5233, Val acc: 71.6049%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 99/120, Train loss: 0.4184, Train acc: 82.0106%, Val loss: 0.5312, Val acc: 74.0741%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 100/120, Train loss: 0.4193, Train acc: 80.4233%, Val loss: 0.5215, Val acc: 72.8395%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 101/120, Train loss: 0.4153, Train acc: 79.3651%, Val loss: 0.5211, Val acc: 72.8395%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 102/120, Train loss: 0.4159, Train acc: 79.8942%, Val loss: 0.5222, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 103/120, Train loss: 0.4163, Train acc: 79.8942%, Val loss: 0.5278, Val acc: 74.0741%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 104/120, Train loss: 0.4156, Train acc: 79.8942%, Val loss: 0.5233, Val acc: 71.6049%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 105/120, Train loss: 0.4142, Train acc: 79.8942%, Val loss: 0.5218, Val acc: 72.8395%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 106/120, Train loss: 0.4160, Train acc: 80.4233%, Val loss: 0.5214, Val acc: 71.6049%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 107/120, Train loss: 0.4163, Train acc: 79.3651%, Val loss: 0.5242, Val acc: 71.6049%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 108/120, Train loss: 0.4150, Train acc: 80.4233%, Val loss: 0.5223, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 109/120, Train loss: 0.4139, Train acc: 79.8942%, Val loss: 0.5216, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 110/120, Train loss: 0.4138, Train acc: 79.8942%, Val loss: 0.5222, Val acc: 71.6049%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 111/120, Train loss: 0.4136, Train acc: 80.4233%, Val loss: 0.5227, Val acc: 71.6049%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 112/120, Train loss: 0.4140, Train acc: 79.8942%, Val loss: 0.5218, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 113/120, Train loss: 0.4136, Train acc: 79.8942%, Val loss: 0.5214, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 114/120, Train loss: 0.4143, Train acc: 79.8942%, Val loss: 0.5213, Val acc: 71.6049%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 115/120, Train loss: 0.4126, Train acc: 80.4233%, Val loss: 0.5215, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 116/120, Train loss: 0.4136, Train acc: 79.8942%, Val loss: 0.5216, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 117/120, Train loss: 0.4125, Train acc: 79.8942%, Val loss: 0.5217, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 118/120, Train loss: 0.4126, Train acc: 79.8942%, Val loss: 0.5218, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 119/120, Train loss: 0.4128, Train acc: 79.8942%, Val loss: 0.5218, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%
# Epoch 120/120, Train loss: 0.4131, Train acc: 79.8942%, Val loss: 0.5218, Val acc: 70.3704%, Best Val loss: 0.5192 Best Val acc: 74.07%

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# read test file
test_data = pd.read_csv('/content/drive/Shareddrives/碩士/深度學習產業應用/week3/heart_dataset_test.csv')
test_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   50    0   2       120   219    0        1      158      0      1.6      1
# 1   58    0   2       120   340    0        1      172      0      0.0      2
# 2   66    0   3       150   226    0        1      114      0      2.6      0
# 3   43    1   0       150   247    0        1      171      0      1.5      2
# 4   69    0   3       140   239    0        1      151      0      1.8      2
#
#    ca  thal  target
# 0   0     2       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   2     2       1

# %%
test_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
test_data = test_data.values
test_data.shape
# Out:
# (31, 14)

# %%
# Convert to PyTorch tensors
x_test = torch.from_numpy(test_data[:, :13]).float()
y_test = torch.from_numpy(test_data[:, 13]).long()

# Create datasets
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for features, labels in test_loader:

        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        predicted = outputs.argmax(-1)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# Test accuracy is 64.51612903225806%
